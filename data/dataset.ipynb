# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Mounted at /content/drive

# %%
import pandas as pd

new_click_data = pd.read_csv('/content/drive/MyDrive/fashion_campus_dataset/click_stream_new.csv')
customer = pd.read_csv('/content/drive/MyDrive/fashion_campus_dataset/customer.csv')
product = pd.read_csv('/content/drive/MyDrive/fashion_campus_dataset/product.csv')
new_transaction = pd.read_csv('/content/drive/MyDrive/fashion_campus_dataset/transaction_new.csv')

# %%
pd.set_option('display.max_columns', None) # 모든 열 출력

# %%
new_click_data.tail(10)
# Out:
#                                     session_id   event_name  \
# 12833592  f5c4bbe0-f977-45bb-af23-6ab524df7777      BOOKING
# 12833593  f5c4bbe0-f977-45bb-af23-6ab524df7777       SEARCH
# 12833594  ad1063b0-a6e5-40a9-aed6-d1b45741e571     HOMEPAGE
# 12833595  ad1063b0-a6e5-40a9-aed6-d1b45741e571  ADD_TO_CART
# 12833596  ad1063b0-a6e5-40a9-aed6-d1b45741e571      BOOKING
# 12833597  ad1063b0-a6e5-40a9-aed6-d1b45741e571       SEARCH
# 12833598  64585e37-3fe7-48d7-b79b-ebcb70230eb2     HOMEPAGE
# 12833599  64585e37-3fe7-48d7-b79b-ebcb70230eb2  ADD_TO_CART
# 12833600  64585e37-3fe7-48d7-b79b-ebcb70230eb2      BOOKING
# 12833601  64585e37-3fe7-48d7-b79b-ebcb70230eb2       SEARCH
#
#                            event_time                              event_id  \
# 12833592  2022-04-09T21:19:08.619449Z  cf4276ea-8a31-4293-afaf-5e923c2be13d
# 12833593  2022-04-09T21:01:31.132472Z  086302b8-62ba-4ce6-8cdc-9924c92176fc
# ...

# %%
mobile_pattern = new_click_data[new_click_data.traffic_source == 'MOBILE'].reset_index()

# %%
mobile_pattern.to_csv('/content/drive/MyDrive/fashion_campus_dataset/mobile_click.csv')

# %%
web_pattern = new_click_data[new_click_data.traffic_source == 'WEB'].reset_index()
web_pattern.to_csv('/content/drive/MyDrive/fashion_campus_dataset/web_click.csv')

# %%
mobile_pattern.groupby(['event_name', 'traffic_source']).agg(['unique'])
# Out:
#                                                                         index  \
#                                                                        unique
# event_name  traffic_source
# ADD_PROMO   MOBILE          [20, 53, 74, 169, 205, 240, 248, 254, 290, 315...
# ADD_TO_CART MOBILE          [3, 12, 13, 14, 15, 16, 17, 18, 19, 39, 52, 66...
# BOOKING     MOBILE          [4, 21, 40, 54, 67, 75, 98, 102, 114, 170, 190...
# CLICK       MOBILE          [28, 30, 36, 58, 60, 61, 63, 68, 70, 77, 79, 8...
# HOMEPAGE    MOBILE          [0, 2, 6, 11, 24, 27, 29, 38, 51, 56, 65, 72, ...
# ITEM_DETAIL MOBILE          [7, 9, 10, 26, 37, 81, 86, 88, 123, 126, 137, ...
# PROMO_PAGE  MOBILE          [32, 33, 62, 64, 78, 92, 93, 107, 124, 125, 16...
# SCROLL      MOBILE          [1, 8, 23, 25, 31, 34, 41, 55, 69, 71, 76, 89,...
# SEARCH      MOBILE          [5, 22, 35, 57, 59, 105, 109, 122, 129, 136, 1...
#
#                                                                    session_id  \
# ...

# %%
mobile_pattern.groupby(['event_name', 'traffic_source']).agg(['count'])
# Out:
#                               index session_id event_time event_id product_id  \
#                               count      count      count    count      count
# event_name  traffic_source
# ADD_PROMO   MOBILE           293838     293838     293838   293838          0
# ADD_TO_CART MOBILE          1743476    1743476    1743476  1743476    1743476
# BOOKING     MOBILE           767254     767254     767254   767254          0
# CLICK       MOBILE          2247457    2247457    2247457  2247457          0
# HOMEPAGE    MOBILE          2237231    2237231    2237231  2237231          0
# ITEM_DETAIL MOBILE          1161552    1161552    1161552  1161552          0
# PROMO_PAGE  MOBILE           544252     544252     544252   544252          0
# SCROLL      MOBILE          1497180    1497180    1497180  1497180          0
# SEARCH      MOBILE          1056064    1056064    1056064  1056064          0
#
#                            quantity item_price payment_status search_keywords  \
# ...

# %%
web_pattern.groupby(['event_name', 'traffic_source']).agg(['unique'])
# Out:
#                                                                         index  \
#                                                                        unique
# event_name  traffic_source
# ADD_PROMO   WEB             [46, 195, 485, 1517, 2245, 2315, 2360, 2756, 2...
# ADD_TO_CART WEB             [43, 44, 45, 194, 484, 926, 1322, 1516, 1634, ...
# BOOKING     WEB             [47, 196, 486, 927, 1323, 1518, 1635, 1756, 20...
# CLICK       WEB             [48, 50, 197, 198, 488, 489, 490, 491, 496, 49...
# HOMEPAGE    WEB             [42, 193, 483, 492, 495, 499, 502, 504, 506, 5...
# ITEM_DETAIL WEB             [49, 500, 510, 512, 547, 552, 566, 574, 576, 5...
# PROMO_PAGE  WEB             [200, 527, 542, 544, 555, 579, 584, 594, 1331,...
# SCROLL      WEB             [199, 201, 487, 493, 507, 519, 535, 556, 557, ...
# SEARCH      WEB             [202, 494, 498, 501, 505, 524, 529, 537, 548, ...
#
#                                                                    session_id  \
# ...

# %%
web_pattern.groupby(['event_name', 'traffic_source']).agg(['count'])
# Out:
#                              index session_id event_time event_id product_id  \
#                              count      count      count    count      count
# event_name  traffic_source
# ADD_PROMO   WEB              32697      32697      32697    32697          0
# ADD_TO_CART WEB             193681     193681     193681   193681     193681
# BOOKING     WEB              85328      85328      85328    85328          0
# CLICK       WEB             250581     250581     250581   250581          0
# HOMEPAGE    WEB             249895     249895     249895   249895          0
# ITEM_DETAIL WEB             128844     128844     128844   128844          0
# PROMO_PAGE  WEB              60679      60679      60679    60679          0
# SCROLL      WEB             166391     166391     166391   166391          0
# SEARCH      WEB             117202     117202     117202   117202          0
#
#                            quantity item_price payment_status search_keywords  \
# ...

# %%
len(new_click_data.session_id.unique())
# Out:
# 895203

# %%
new_click_data.event_name.unique()
# Out:
# array(['HOMEPAGE', 'SCROLL', 'ADD_TO_CART', 'BOOKING', 'SEARCH',
#        'ITEM_DETAIL', 'ADD_PROMO', 'CLICK', 'PROMO_PAGE'], dtype=object)

# %%
new_click_data.traffic_source.unique()
# Out:
# array(['MOBILE', 'WEB'], dtype=object)

# %%
new_click_data.groupby('session_id')

# %%
customer.tail(2)
# Out:
#        customer_id first_name last_name                              username  \
# 99998        75597     Ajimat    Mansur  35cd82f3-6b86-42a2-bb15-933770d7f250
# 99999        40573       Yani     Usada  f5a2ab29-481d-49e6-960e-cb864ee1ed5a
#
#                                                    email gender   birthdate  \
# 99998  35cd82f3_6b86_42a2_bb15_933770d7f250@startupca...      M  2000-09-13
# 99999  f5a2ab29_481d_49e6_960e_cb864ee1ed5a@startupca...      F  1987-09-10
#
#       device_type                             device_id device_version  \
# 99998     Android  3b209c58-d305-4b46-9363-b90a3914f008    Android 7.1
# 99999     Android  b6bc29e0-5a22-47af-b31e-0972aafd4cab  Android 3.2.6
#
#        home_location_lat  home_location_long home_location home_country  \
# 99998          -2.173114          101.495913         Jambi    Indonesia
# 99999          -6.524369          106.283232        Banten    Indonesia
#
#       first_join_date
# 99998      2020-05-31
# ...

# %%
product.tail(2)
# Out:
#           id gender masterCategory subCategory            articleType  \
# 44444  46694  Women  Personal Care   Fragrance  Perfume and Body Mist
# 44445  51623  Women    Accessories     Watches                Watches
#
#       baseColour  season    year   usage  \
# 44444       Blue  Spring  2017.0  Casual
# 44445       Pink  Winter  2016.0  Casual
#
#                                     productDisplayName
# 44444                   Rasasi Women Blue Lady Perfume
# 44445  Fossil Women Pink Dial Chronograph Watch ES3050

# %%
new_transaction.tail(2)
# Out:
#                           created_at  customer_id  \
# 1254583  2019-12-18T11:01:09.623382Z        87319
# 1254584  2019-12-19T12:47:14.701215Z        58180
#
#                                    booking_id  \
# 1254583  af7f291a-b01b-4bfd-89a9-237b16368b15
# 1254584  b242e188-5f94-4448-a038-c5865842374b
#
#                                    session_id payment_method payment_status  \
# 1254583  bb6e5426-a3f3-426a-b99d-79173eaa234b    Credit Card        Success
# 1254584  5e3183df-198b-40e0-b861-27ef694a832a          Gopay        Success
#
#          promo_amount promo_code  shipment_fee          shipment_date_limit  \
# 1254583          4503     AZ2022             0  2019-12-23T22:56:46.831720Z
# 1254584          4724    BUYMORE         10000  2019-12-23T06:02:05.828334Z
#
#          shipment_location_lat  shipment_location_long  total_amount  \
# 1254583              -7.155977              110.891858        184143
# ...

# %%
tran_product = pd.merge(new_transaction, product, left_on='product_id', right_on='id', how='left')
tran_product.tail()
# Out:
#                           created_at  customer_id  \
# 1254580  2021-09-21T22:10:05.074873Z        25121
# 1254581  2021-12-09T07:35:18.222046Z        34829
# 1254582  2021-12-11T01:20:36.944593Z        99645
# 1254583  2019-12-18T11:01:09.623382Z        87319
# 1254584  2019-12-19T12:47:14.701215Z        58180
#
#                                    booking_id  \
# 1254580  66f02fa4-c62e-497a-8b6e-be239009b50a
# 1254581  ccde6b83-ee42-4cce-b2cd-976574886eac
# 1254582  5bcd3434-1dc6-44bb-ae63-fd19714cbd6c
# 1254583  af7f291a-b01b-4bfd-89a9-237b16368b15
# 1254584  b242e188-5f94-4448-a038-c5865842374b
#
#                                    session_id payment_method payment_status  \
# 1254580  484eecde-9f4a-42de-a8df-7ce6668101f4     Debit Card         Failed
# 1254581  954e1211-4d45-4d0b-ba84-53e80119592c            OVO        Success
# 1254582  e6e6c108-abd0-49a2-b0a5-691117f9cfe1    Credit Card        Success
# ...

# %%
tran_prod_cus = pd.merge(tran_product, customer, on='customer_id', how='left')
tran_prod_cus.tail()
# Out:
#                           created_at  customer_id  \
# 1254580  2021-09-21T22:10:05.074873Z        25121
# 1254581  2021-12-09T07:35:18.222046Z        34829
# 1254582  2021-12-11T01:20:36.944593Z        99645
# 1254583  2019-12-18T11:01:09.623382Z        87319
# 1254584  2019-12-19T12:47:14.701215Z        58180
#
#                                    booking_id  \
# 1254580  66f02fa4-c62e-497a-8b6e-be239009b50a
# 1254581  ccde6b83-ee42-4cce-b2cd-976574886eac
# 1254582  5bcd3434-1dc6-44bb-ae63-fd19714cbd6c
# 1254583  af7f291a-b01b-4bfd-89a9-237b16368b15
# 1254584  b242e188-5f94-4448-a038-c5865842374b
#
#                                    session_id payment_method payment_status  \
# 1254580  484eecde-9f4a-42de-a8df-7ce6668101f4     Debit Card         Failed
# 1254581  954e1211-4d45-4d0b-ba84-53e80119592c            OVO        Success
# 1254582  e6e6c108-abd0-49a2-b0a5-691117f9cfe1    Credit Card        Success
# ...
